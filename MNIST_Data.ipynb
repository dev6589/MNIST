# %% [markdown]
# <a href="https://colab.research.google.com/github/dev6589/MNIST/blob/main/MNIST_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries

#--> Keras and Tensorflow
import tensorflow as tf
from tensorflow import keras
fashion_mnist = keras.datasets.fashion_mnist

# Tupple 1                    # Tupple 2
(X_train_full, y_train_full),(X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
mnist = keras.datasets.mnist

# %%
(X_train_full_1, y_train_full_1), (X_test_1, y_test_1) = mnist.load_data()

# %%
import matplotlib.pyplot as plt

# %%
X_train_full[0].shape #(length, breadth, channels)
# Out:
# (28, 28)

# %%
plt.imshow(X_train_full[0], cmap='gray')
plt.show()

# %%
y_train_full[0]
# Out:
# 9

# %%
# first 25 images
plt.figure(figsize=(12,12))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(X_train_full[i], cmap='gray')
  plt.title(y_train_full[i])
  plt.axis('off')

# %%
class_names = ["Top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
# first 25 images
plt.figure(figsize=(12,12))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(X_train_full[i], cmap='gray')
  plt.title(class_names[y_train_full[i]])
  plt.axis('off')

# %%
import numpy as np

a = np.full((2,2),1)
a #(2, 2), (1,4), (4,1)

# [28,28] --> [784,1], [1,784]
# Out:
# array([[1, 1],
#        [1, 1]])

# %%
X_train_full_updated = X_train_full/255.0 # scale the features

# %%
y_train_full[1]
# Out:
# 0

# %%
y_train_full_updated = keras.utils.to_categorical(y_train_full)
y_test_updated = keras.utils.to_categorical(y_test)

# %%
# Import the required layers
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# Model object
model = Sequential()

# add layers
model.add(Flatten(input_shape = [28, 28])) #---> Input layer
model.add(Dense(300, activation='relu')) #--> Hidden Layer 1
model.add(Dense(100, activation='relu')) #--> Hidden Layer 2

#--> Add your own layer
model.add(Dense(10, activation='softmax')) #---> Output layer
model.summary()

# Callback
cb = EarlyStopping(patience=10)


# Compile the model #--> SGD, Adam, RMSPROP, ..... # error function
model.compile(optimizer='sgd', loss = 'categorical_crossentropy', metrics=['accuracy'])

# Fit the model
hist = model.fit(X_train_full_updated, y_train_full_updated, epochs=1000, validation_split=0.2, callbacks=cb)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 300)               235500
# _________________________________________________________________
# dense_22 (Dense)             (None, 100)               30100
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1500/1500 [==============================] - 6s 4ms/step - loss: 1.0485 - accuracy: 0.6738 - val_loss: 0.5708 - val_accuracy: 0.7882
# Epoch 2/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5209 - accuracy: 0.8221 - val_loss: 0.4695 - val_accuracy: 0.8351
# Epoch 3/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4583 - accuracy: 0.8397 - val_loss: 0.4408 - val_accuracy: 0.8443
# Epoch 4/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4256 - accuracy: 0.8494 - val_loss: 0.4290 - val_accuracy: 0.8454
# Epoch 5/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3987 - accuracy: 0.8633 - val_loss: 0.4047 - val_accuracy: 0.8608
# Epoch 6/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3860 - accuracy: 0.8673 - val_loss: 0.3933 - val_accuracy: 0.8615
# Epoch 7/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3762 - accuracy: 0.8680 - val_loss: 0.3833 - val_accuracy: 0.8657
# Epoch 8/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3603 - accuracy: 0.8731 - val_loss: 0.3744 - val_accuracy: 0.8692
# Epoch 9/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3428 - accuracy: 0.8787 - val_loss: 0.3640 - val_accuracy: 0.8703
# Epoch 10/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3423 - accuracy: 0.8786 - val_loss: 0.3555 - val_accuracy: 0.8733
# Epoch 11/1000
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3264 - accuracy: 0.8849 - val_loss: 0.3502 - val_accuracy: 0.8766
# Epoch 12/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3289 - accuracy: 0.8825 - val_loss: 0.3556 - val_accuracy: 0.8744
# Epoch 13/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3175 - accuracy: 0.8878 - val_loss: 0.3500 - val_accuracy: 0.8749
# Epoch 14/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3046 - accuracy: 0.8895 - val_loss: 0.3517 - val_accuracy: 0.8734
# Epoch 15/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3017 - accuracy: 0.8923 - val_loss: 0.3539 - val_accuracy: 0.8742
# Epoch 16/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2902 - accuracy: 0.8956 - val_loss: 0.3373 - val_accuracy: 0.8802
# Epoch 17/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2919 - accuracy: 0.8952 - val_loss: 0.3270 - val_accuracy: 0.8833
# Epoch 18/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2837 - accuracy: 0.8966 - val_loss: 0.3252 - val_accuracy: 0.8841
# Epoch 19/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2836 - accuracy: 0.8971 - val_loss: 0.3267 - val_accuracy: 0.8812
# Epoch 20/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2740 - accuracy: 0.9011 - val_loss: 0.3285 - val_accuracy: 0.8856
# Epoch 21/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2715 - accuracy: 0.9024 - val_loss: 0.3331 - val_accuracy: 0.8806
# Epoch 22/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2576 - accuracy: 0.9073 - val_loss: 0.3224 - val_accuracy: 0.8859
# Epoch 23/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2563 - accuracy: 0.9072 - val_loss: 0.3222 - val_accuracy: 0.8848
# Epoch 24/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2509 - accuracy: 0.9114 - val_loss: 0.3260 - val_accuracy: 0.8842
# Epoch 25/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2459 - accuracy: 0.9117 - val_loss: 0.3182 - val_accuracy: 0.8856
# Epoch 26/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2395 - accuracy: 0.9146 - val_loss: 0.3189 - val_accuracy: 0.8841
# Epoch 27/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2391 - accuracy: 0.9142 - val_loss: 0.3223 - val_accuracy: 0.8861
# Epoch 28/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2360 - accuracy: 0.9170 - val_loss: 0.3121 - val_accuracy: 0.8896
# Epoch 29/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2361 - accuracy: 0.9149 - val_loss: 0.3265 - val_accuracy: 0.8828
# Epoch 30/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2303 - accuracy: 0.9170 - val_loss: 0.3181 - val_accuracy: 0.8843
# Epoch 31/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2202 - accuracy: 0.9211 - val_loss: 0.3084 - val_accuracy: 0.8924
# Epoch 32/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2232 - accuracy: 0.9199 - val_loss: 0.3236 - val_accuracy: 0.8832
# Epoch 33/1000
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2182 - accuracy: 0.9222 - val_loss: 0.3050 - val_accuracy: 0.8902
# Epoch 34/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2198 - accuracy: 0.9214 - val_loss: 0.3144 - val_accuracy: 0.8877
# Epoch 35/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2133 - accuracy: 0.9244 - val_loss: 0.3111 - val_accuracy: 0.8911
# Epoch 36/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2078 - accuracy: 0.9257 - val_loss: 0.3251 - val_accuracy: 0.8870
# Epoch 37/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2041 - accuracy: 0.9266 - val_loss: 0.3054 - val_accuracy: 0.8926
# Epoch 38/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2065 - accuracy: 0.9268 - val_loss: 0.3115 - val_accuracy: 0.8904
# Epoch 39/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1978 - accuracy: 0.9292 - val_loss: 0.3020 - val_accuracy: 0.8925
# Epoch 40/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1929 - accuracy: 0.9317 - val_loss: 0.3053 - val_accuracy: 0.8914
# Epoch 41/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1938 - accuracy: 0.9323 - val_loss: 0.3104 - val_accuracy: 0.8880
# Epoch 42/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1941 - accuracy: 0.9322 - val_loss: 0.3267 - val_accuracy: 0.8856
# Epoch 43/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1836 - accuracy: 0.9350 - val_loss: 0.3144 - val_accuracy: 0.8890
# Epoch 44/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1866 - accuracy: 0.9334 - val_loss: 0.3105 - val_accuracy: 0.8918
# Epoch 45/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1748 - accuracy: 0.9382 - val_loss: 0.3067 - val_accuracy: 0.8918
# Epoch 46/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1772 - accuracy: 0.9373 - val_loss: 0.3436 - val_accuracy: 0.8792
# Epoch 47/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1740 - accuracy: 0.9377 - val_loss: 0.3345 - val_accuracy: 0.8865
# Epoch 48/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1723 - accuracy: 0.9388 - val_loss: 0.3101 - val_accuracy: 0.8940
# Epoch 49/1000
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1665 - accuracy: 0.9408 - val_loss: 0.3071 - val_accuracy: 0.8917

# %%
h  = hist.history
plt.plot(h['accuracy'], label = 'Train accuracy')
plt.plot(h['val_accuracy'], label = 'Validation Accuracy')
plt.legend()
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(h['loss'], label = 'Train Loss')
plt.plot(h['val_loss'], label = 'Validation Loss')
plt.legend()
plt.xlabel('Number of epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# Homework

# %%
# first 25 images
plt.figure(figsize=(12,12))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(X_train_full_1[i], cmap='gray')
  plt.title(y_train_full_1[i])
  plt.axis('off')
